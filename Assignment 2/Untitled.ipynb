# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
da = pd.read_excel("insurance.xlsx")

# %%
da.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
da.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   gender    1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
da.isnull()
# Out:
#         age  gender    bmi  children  smoker  region  charges
# 0     False   False  False     False   False   False    False
# 1     False   False  False     False   False   False    False
# 2     False   False  False     False   False   False    False
# 3     False   False  False     False   False   False    False
# 4     False   False  False     False   False   False    False
# ...     ...     ...    ...       ...     ...     ...      ...
# 1333  False   False  False     False   False   False    False
# 1334  False   False  False     False   False   False    False
# 1335  False   False  False     False   False   False    False
# 1336  False   False  False     False   False   False    False
# 1337  False   False  False     False   False   False    False
#
# [1338 rows x 7 columns]

# %%
da.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# # ------- Measues of Central Tendency -------

# %%
da.charges.mean()
# Out:
# 13270.422265141257

# %%
da.charges.median()
# Out:
# 9382.033

# %%
da.bmi.mean()
# Out:
# 30.66339686098655

# %%
da.bmi.median()
# Out:
# 30.4

# %%
da.region.mode()
# Out:
# 0    southeast
# Name: region, dtype: object

# %%
da.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
import seaborn as sns

# %%
sns.histplot(da[["charges"]])
# Out:
# <Axes: ylabel='Count'>

# %%
da.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 da.corr()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
plt.figure(figsize = (10,10))
sns.heatmap(da.corr(), annot = True)
plt.savefig("Ashik.png")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 2
#       1 plt.figure(figsize = (10,10))
# ----> 2 sns.heatmap(da.corr(), annot = True)
#       3 plt.savefig("Ashik.png")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
# ...

# %%
da.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# # Handel NAN Value(NAN == NULL)

# %%
Mean_charges = da.charges.mean()

# %%
Mean_charges
# Out:
# 13270.422265141257

# %%
da.charges = da.charges.fillna(Mean_charges)

# %%
da.isnull().sum()
# Out:
# age         0
# gender      0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
da.charges.iloc[20]
# Out:
# 13228.84695

# %%
da[15:24]
# Out:
#     age  gender     bmi  children smoker     region      charges
# 15   19    male  24.600         1     no  southwest   1837.23700
# 16   52  female  30.780         1     no  northeast  10797.33620
# 17   23    male  23.845         0     no  northeast   2395.17155
# 18   56    male  40.300         0     no  southwest  10602.38500
# 19   30    male  35.300         0    yes  southwest  36837.46700
# 20   60  female  36.005         0     no  northeast  13228.84695
# 21   30  female  32.400         1     no  southwest   4149.73600
# 22   18    male  34.100         0     no  southeast   1137.01100
# 23   34  female  31.920         1    yes  northeast  37701.87680

# %%
da.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
da1 = da.copy()
da2 = da.copy()
da3 = da.copy()
da4 = da.copy()
da5 = da.copy()
da6 = da.copy()
da7 = da.copy()
da8 = da.copy()
da9 = da.copy()
da10 = da.copy()

# %% [markdown]
# # Without Encoding

# %%
da.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
 bmi1 = da.bmi.unique()

# %%
bmi1
# Out:
# array([27.9  , 33.77 , 33.   , 22.705, 28.88 , 25.74 , 33.44 , 27.74 ,
#        29.83 , 25.84 , 26.22 , 26.29 , 34.4  , 39.82 , 42.13 , 24.6  ,
#        30.78 , 23.845, 40.3  , 35.3  , 36.005, 32.4  , 34.1  , 31.92 ,
#        28.025, 27.72 , 23.085, 32.775, 17.385, 36.3  , 35.6  , 26.315,
#        28.6  , 28.31 , 36.4  , 20.425, 32.965, 20.8  , 36.67 , 39.9  ,
#        26.6  , 36.63 , 21.78 , 30.8  , 37.05 , 37.3  , 38.665, 34.77 ,
#        24.53 , 35.2  , 35.625, 33.63 , 28.   , 34.43 , 28.69 , 36.955,
#        31.825, 31.68 , 22.88 , 37.335, 27.36 , 33.66 , 24.7  , 25.935,
#        22.42 , 28.9  , 39.1  , 36.19 , 23.98 , 24.75 , 28.5  , 28.1  ,
#        32.01 , 27.4  , 34.01 , 29.59 , 35.53 , 39.805, 26.885, 38.285,
#        37.62 , 41.23 , 34.8  , 22.895, 31.16 , 27.2  , 26.98 , 39.49 ,
#        24.795, 31.3  , 38.28 , 19.95 , 19.3  , 31.6  , 25.46 , 30.115,
#        29.92 , 27.5  , 28.4  , 30.875, 27.94 , 35.09 , 29.7  , 35.72 ,
# ...

# %%
da.bmi = da.bmi.replace([27, 33,30], [1,2,3])

# %%
da.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male   2.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
da1.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
da1.bmi = le.fit_transform(da1.bmi)

# %%
da1.head()
# Out:
#    age  gender  bmi  children smoker     region      charges
# 0   19  female  197         0    yes  southwest  16884.92400
# 1   18    male  350         1     no  southeast   1725.55230
# 2   28    male  331         3     no  southeast   4449.46200
# 3   33    male   73         0     no  northwest  21984.47061
# 4   32    male  223         0     no  northwest   3866.85520

# %% [markdown]
# # Using Loop

# %%
da2.columns
# Out:
# Index(['age', 'gender', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
for col in da2.columns:
    if da2[col].dtype == np.number:
        continue
    else:
        da2[col] = le.fit_transform(da2[col])

# %%
da2.head()
# Out:
#    age  gender     bmi  children  smoker  region      charges
# 0    1       0  27.900         0       1       3  16884.92400
# 1    0       1  33.770         1       0       2   1725.55230
# 2   10       1  33.000         3       0       2   4449.46200
# 3   15       1  22.705         0       0       1  21984.47061
# 4   14       1  28.880         0       0       1   3866.85520

# %% [markdown]
# # Another Way

# %%
from pandas.core.dtypes.common import is_numeric_dtype

# %%
for i in da3.columns:
    if is_numeric_dtype(da3[i]):
        continue
    else:
        da3[i] = le.fit_transform(da3[i])

# %%
da3.head()
# Out:
#    age  gender     bmi  children  smoker  region      charges
# 0   19       0  27.900         0       1       3  16884.92400
# 1   18       1  33.770         1       0       2   1725.55230
# 2   28       1  33.000         3       0       2   4449.46200
# 3   33       1  22.705         0       0       1  21984.47061
# 4   32       1  28.880         0       0       1   3866.85520

# %% [markdown]
# # One Hot Encoding

# %%
dummy = pd.get_dummies(da4['bmi'], columns = da4.bmi.unique)

# %%
dummy.head()
# Out:
#    15.960  16.815  17.195  17.290  17.385  17.400  17.480  17.670  17.765  \
# 0   False   False   False   False   False   False   False   False   False
# 1   False   False   False   False   False   False   False   False   False
# 2   False   False   False   False   False   False   False   False   False
# 3   False   False   False   False   False   False   False   False   False
# 4   False   False   False   False   False   False   False   False   False
#
#    17.800  ...  46.750  47.410  47.520  47.600  47.740  48.070  49.060  \
# 0   False  ...   False   False   False   False   False   False   False
# 1   False  ...   False   False   False   False   False   False   False
# 2   False  ...   False   False   False   False   False   False   False
# 3   False  ...   False   False   False   False   False   False   False
# 4   False  ...   False   False   False   False   False   False   False
#
#    50.380  52.580  53.130
# 0   False   False   False
# 1   False   False   False
# ...

# %%
da4.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
da4.drop('bmi', axis = 1, inplace = True)

# %%
da4.head()
# Out:
#    age  gender  children smoker     region      charges
# 0   19  female         0    yes  southwest  16884.92400
# 1   18    male         1     no  southeast   1725.55230
# 2   28    male         3     no  southeast   4449.46200
# 3   33    male         0     no  northwest  21984.47061
# 4   32    male         0     no  northwest   3866.85520

# %% [markdown]
# # Dummy variable Trap

# %%
dummy = pd.get_dummies(da5['bmi'],columns=da5.bmi.unique,drop_first=True,prefix='bmi')

# %%
dummy.head()
# Out:
#    bmi_16.815  bmi_17.195  bmi_17.29  bmi_17.385  bmi_17.4  bmi_17.48  \
# 0       False       False      False       False     False      False
# 1       False       False      False       False     False      False
# 2       False       False      False       False     False      False
# 3       False       False      False       False     False      False
# 4       False       False      False       False     False      False
#
#    bmi_17.67  bmi_17.765  bmi_17.8  bmi_17.86  ...  bmi_46.75  bmi_47.41  \
# 0      False       False     False      False  ...      False      False
# 1      False       False     False      False  ...      False      False
# 2      False       False     False      False  ...      False      False
# 3      False       False     False      False  ...      False      False
# 4      False       False     False      False  ...      False      False
#
#    bmi_47.52  bmi_47.6  bmi_47.74  bmi_48.07  bmi_49.06  bmi_50.38  bmi_52.58  \
# ...

# %%
da6 = pd.concat([da4,dummy],axis=1)

# %%
da6.head()
# Out:
#    age  gender  children smoker     region      charges  bmi_16.815  \
# 0   19  female         0    yes  southwest  16884.92400       False
# 1   18    male         1     no  southeast   1725.55230       False
# 2   28    male         3     no  southeast   4449.46200       False
# 3   33    male         0     no  northwest  21984.47061       False
# 4   32    male         0     no  northwest   3866.85520       False
#
#    bmi_17.195  bmi_17.29  bmi_17.385  ...  bmi_46.75  bmi_47.41  bmi_47.52  \
# 0       False      False       False  ...      False      False      False
# 1       False      False       False  ...      False      False      False
# 2       False      False       False  ...      False      False      False
# 3       False      False       False  ...      False      False      False
# 4       False      False       False  ...      False      False      False
#
#    bmi_47.6  bmi_47.74  bmi_48.07  bmi_49.06  bmi_50.38  bmi_52.58  bmi_53.13
# ...

# %% [markdown]
# # One hot encoding using Loop

# %%
da7.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
cols = ['bmi']
for col in cols:
    dummy = pd.get_dummies(da7[col], drop_first = True, prefix = 'bmi')
    da8 = pd.concat([da7,dummy], axis = 1).drop(col, axis = 1)
    da8.head()

# %% [markdown]
# # Ordinal Encoding

# %%
BMI = da9.bmi.unique()

# %%
BMI
# Out:
# array([27.9  , 33.77 , 33.   , 22.705, 28.88 , 25.74 , 33.44 , 27.74 ,
#        29.83 , 25.84 , 26.22 , 26.29 , 34.4  , 39.82 , 42.13 , 24.6  ,
#        30.78 , 23.845, 40.3  , 35.3  , 36.005, 32.4  , 34.1  , 31.92 ,
#        28.025, 27.72 , 23.085, 32.775, 17.385, 36.3  , 35.6  , 26.315,
#        28.6  , 28.31 , 36.4  , 20.425, 32.965, 20.8  , 36.67 , 39.9  ,
#        26.6  , 36.63 , 21.78 , 30.8  , 37.05 , 37.3  , 38.665, 34.77 ,
#        24.53 , 35.2  , 35.625, 33.63 , 28.   , 34.43 , 28.69 , 36.955,
#        31.825, 31.68 , 22.88 , 37.335, 27.36 , 33.66 , 24.7  , 25.935,
#        22.42 , 28.9  , 39.1  , 36.19 , 23.98 , 24.75 , 28.5  , 28.1  ,
#        32.01 , 27.4  , 34.01 , 29.59 , 35.53 , 39.805, 26.885, 38.285,
#        37.62 , 41.23 , 34.8  , 22.895, 31.16 , 27.2  , 26.98 , 39.49 ,
#        24.795, 31.3  , 38.28 , 19.95 , 19.3  , 31.6  , 25.46 , 30.115,
#        29.92 , 27.5  , 28.4  , 30.875, 27.94 , 35.09 , 29.7  , 35.72 ,
# ...

# %%
da9.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
from sklearn.preprocessing import OrdinalEncoder
od = OrdinalEncoder(categories=[BMI])

# %%
ev = od.fit_transform(da9[['bmi']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 ev = od.fit_transform(da9[['bmi']])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:878, in TransformerMixin.fit_transform(self, X, y, **fit_params)
# ...

# %%
ev
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 ev
#
# NameError: name 'ev' is not defined

# %%
ev = pd.DataFrame(encoded_values,columns=['bmi'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 ev = pd.DataFrame(encoded_values,columns=['bmi'])
#
# NameError: name 'encoded_values' is not defined

# %%
da9 = pd.concat([da9.drop('Area',axis=1),encoded_values],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 da9 = pd.concat([da9.drop('Area',axis=1),encoded_values],axis=1)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
# ...

# %%
da9.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
